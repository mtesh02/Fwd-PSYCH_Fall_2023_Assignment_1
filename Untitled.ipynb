# %%
# STUDENT NAME: MAHMUDUL HASAN ANIK
# STUDENT NUMBER: S370297
#INSTITUTION: THE CATHOLIC UNIVERSITY OF EASTERN AFRICA

# %%
# import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read data from the Excel file
data = pd.read_csv('screentime.csv')

# %%
# Plotting
plt.figure(figsize=(10, 5))
plt.plot(data['Day'], data['Screen Time (minutes)'], marker='o', color='b')
plt.title('Screen Time Behavior')
plt.xlabel('Day')
plt.ylabel('Screen Time (minutes)')
plt.grid(True)

# %%
# Show the plot
plt.show()
